# %% [markdown]
# <h2 style="color:green" align="center">Machine Learning With Python: Linear Regression With One Variable</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price($USD)")
plt.scatter(df.area,df.price, color = "green", marker = "X")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
# This is the syntax of how predict should be given --> reg.predict([[]])
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
#co-efficient w value
reg.coef_
# Out:
# array([135.78767123])

# %%
#intercept b value
reg.intercept_
# Out:
# 180616.43835616432

# %%
# f[x] = wx + b
# w = 135.78767123
# b = 180616.43835616432
# x = 3300
# which gives --> 628715.75342466

# %%
reg.predict([[5500]])
# Out:
# C:\Users\madhu\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([927448.63013699])

# %%
# %matplotlib inline
plt.xlabel("area(sq ft)")
plt.ylabel("price($USD)")
plt.scatter(df.area,df.price, color = "green", marker = "X")
plt.plot(df.area,reg.predict(df[['area']]),color="red")

# %%
d = pd.read_csv("areas.csv")

# %%
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv('predictions.csv', index = False)
